# %% [markdown]
# <a href="https://colab.research.google.com/github/ParthV02/ML-DL-Practicals/blob/master/MLDL_Practical_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
best_params = results.sort_values(by='mean_test_score', ascending=False).iloc[0]
best_C = best_params['param_C']
best_gamma = best_params['param_gamma']

print(f"Best C: {best_C}")
print(f"Best gamma: {best_gamma}")
# Out:
# Best C: 10.0
# Best gamma: 0.01

# %%
from sklearn.svm import SVC

# Instantiate the SVM classifier with the best parameters
svm_model = SVC(C=best_C, gamma=best_gamma, kernel='rbf')

# Train the SVM model
svm_model.fit(X_train_scaled, y_train)
print("SVM model trained successfully with best C and gamma values.")
# Out:
# SVM model trained successfully with best C and gamma values.

# %%
from sklearn.metrics import classification_report

# Make predictions on the scaled test data
y_pred = svm_model.predict(X_test_scaled)

# Generate and print the classification report
report = classification_report(y_test, y_pred)
print("Classification Report:")
print(report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98        42
#            1       0.99      0.99      0.99        72
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the confusion matrix
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
print("Confusion matrix heatmap displayed successfully.")
# Out:
# Confusion matrix heatmap displayed successfully.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a heatmap of the pivot_table to visualize hyperparameter tuning scores
plt.figure(figsize=(10, 8))
sns.heatmap(pivot_table, annot=True, cmap='viridis', fmt='.3f')
plt.title('Hyperparameter Tuning Scores (mean_test_score)')
plt.xlabel('Gamma')
plt.ylabel('C')
plt.show()
print("Hyperparameter tuning scores heatmap displayed successfully.")
# Out:
# Hyperparameter tuning scores heatmap displayed successfully.
